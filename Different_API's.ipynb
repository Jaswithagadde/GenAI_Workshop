# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaswithagadde/GenAI_Workshop/blob/main/Different_API's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GOOGLE GEMINI**

# %%
from google import genai

# %%
from google.colab import userdata

# %%
api_key = userdata.get("gemini_key")

# %%
client = genai.Client(api_key=api_key)

# %%
prompt = input("Enter a prompt: ")

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

# %%
print(response)

# %%
print("\nGenerated Response:")

print(response.text)

# %% [markdown]
# **GORQ**

# %%
# !pip install groq

# %%
from groq import Groq

# %%
api_key = userdata.get("groq_key")

# %%
client = Groq(api_key=api_key)

# %%
prompt = input("Enter a prompt: ")

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",

    messages=[
        {"role": "user", "content": prompt}
    ]
)

# %%
print("\nGenerated Response:")

print(response.choices[0].message.content)

# %% [markdown]
# OPEN ROUTER

# %%
from openai import OpenAI

# %%
api_key = userdata.get("open_key")

# %%
client = OpenAI(
    api_key= api_key,
    base_url="https://openrouter.ai/api/v1"
)

# %%
prompt = input("Enter a prompt: ")

# %%
response = client.chat.completions.create(
    model="meta-llama/llama-3.3-70b-instruct",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

# %%
print("\nGenerated Response:")
print(response.choices[0].message.content)
